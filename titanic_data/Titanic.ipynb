# %%
import sklearn.preprocessing as pp
from sklearn.feature_extraction import DictVectorizer

v =  DictVectorizer(sparse=False)
D = [{'foo': 'Banana', 'bar': 2}, {'foo': 'Apple', 'bar': 1}, {'foo': 'Apple', 'bar': 1} ]
print(v.fit_transform(D))

v.get_feature_names()
# Out:
# [[ 2.  0.  1.]
#  [ 1.  1.  0.]
#  [ 1.  1.  0.]]
# ['bar', 'foo=Apple', 'foo=Banana']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import Imputer
import numpy as np

def write_result(result):
    with open('result.csv', 'w+') as f:
        f.write("PassengerId,Survived\n")
        for row in result:
            f.write(" %d,%d\n" % row)

classifier = LogisticRegression(C=1, 
                                penalty='l2', 
                                #solver='lbfgs',
                                tol=0.01)



imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
dropped_columns = ['PassengerId','Name','Ticket','Fare','Cabin','Embarked']

df_train = pd.read_csv("../titanic_data/train.csv")
df_test = pd.read_csv("../titanic_data/test.csv")


df_test_features = df_test.drop(dropped_columns,axis=1)
df_train_features = df_train.drop(dropped_columns + ["Survived"], axis=1)


df_train_survived = df_train.iloc[:,1]

df_train_features = pd.get_dummies(df_train_features)

df_test_features = pd.get_dummies(df_test_features)
df_test_idx = df_test.iloc[:,0]

df_train_features = imputer.fit_transform(df_train_features)
df_test_features = imputer.fit_transform(df_test_features)

classifier.fit(df_train_features, df_train_survived)

classifier.predict(df_test_features)
result_labels = classifier.predict(df_test_features)

ys = zip(df_test_idx,result_labels)

write_result(ys)


print('Done!')
# Out:
# Done!

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import Imputer
from sklearn.feature_extraction import DictVectorizer

import numpy as np


def write_result(result):
    with open('result.csv', 'w+') as f:
        f.write("PassengerId,Survived\n")
        for row in result:
            f.write(" %d,%d\n" % row)

classifier = LogisticRegression(C=1, 
                                penalty='l2', 
                                #solver='lbfgs',
                                tol=0.01)

vectorizer = DictVectorizer(sparse=False)

imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
dropped_columns = ['PassengerId',
                   'Name',
                   'Ticket',
                   'Fare',
                   #'Cabin',
                   'Embarked']

df_train = pd.read_csv("../titanic_data/train.csv")
df_test = pd.read_csv("../titanic_data/test.csv")


df_test_features = df_test.drop(dropped_columns,axis=1)
df_train_features = df_train.drop(dropped_columns + ["Survived"], axis=1)

dict_train_features = df_train_features.to_dict( orient = 'records' )


fit(X[, y])

# df_train_survived = df_train.iloc[:,1]

# df_train_features = pd.get_dummies(df_train_features)

# df_test_features = pd.get_dummies(df_test_features)
# df_test_idx = df_test.iloc[:,0]

# df_train_features = imputer.fit_transform(df_train_features)
# df_test_features = imputer.fit_transform(df_test_features)

# classifier.fit(df_train_features, df_train_survived)

# classifier.predict(df_test_features)
# result_labels = classifier.predict(df_test_features)

# ys = zip(df_test_idx,result_labels)

# write_result(ys)


dict_train_features
# Out:
# [{'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 38.0,
#   'Cabin': 'C85',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': 'C123',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 54.0,
#   'Cabin': 'E46',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 3},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 14.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 4.0,
#   'Cabin': 'G6',
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 58.0,
#   'Cabin': 'C103',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': nan,
#   'Parch': 5,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 14.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 55.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': 'D56',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 15.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': 'A6',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 8.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': 38.0,
#   'Cabin': nan,
#   'Parch': 5,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': 'C23 C25 C27',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 3},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 40.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'B78',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 66.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 14.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 40.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 3.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 7.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 49.0,
#   'Cabin': 'D33',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 65.0,
#   'Cabin': 'B30',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'C52',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 28.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 5.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 11.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 5},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': 'B28',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 45.0,
#   'Cabin': 'C83',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 4.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 3},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': 'F33',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 4},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 5},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': 'F G73',
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 0.83,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 3,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': 'C23 C25 C27',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 46.0,
#   'Cabin': 'E31',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 59.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 71.0,
#   'Cabin': 'A5',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': 'D10 D12',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': 'D26',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 37.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 47.0,
#   'Cabin': 'C110',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 14.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 70.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 24.0,
#   'Cabin': 'B58 B60',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 4},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 32.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 32.5,
#   'Cabin': 'E101',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 54.0,
#   'Cabin': 'D26',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 12.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'F E69',
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 47.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': 'D47',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 37.0,
#   'Cabin': 'C123',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': 'B86',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 9.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 36.5,
#   'Cabin': 'F2',
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 51.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': 'C2',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 55.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 40.5,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 51.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 8},
#  {'Age': 44.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 40.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 1.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 9.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'E33',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 4,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 61.0,
#   'Cabin': 'B19',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 4.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 1.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 56.0,
#   'Cabin': 'A7',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 3},
#  {'Age': 50.0,
#   'Cabin': 'C49',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 8},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 9.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 1.0,
#   'Cabin': 'F4',
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 4.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'A32',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 40.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 36.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 3.0,
#   'Cabin': 'F2',
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 44.0,
#   'Cabin': 'B4',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 58.0,
#   'Cabin': 'B80',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 8},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 45.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': 'G6',
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 40.0,
#   'Cabin': 'A31',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 31.0,
#   'Cabin': 'D36',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 32.0,
#   'Cabin': 'D15',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 51.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': 'C93',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 20.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': 35.0,
#   'Cabin': 'C83',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 59.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 5.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 4},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 44.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 8.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 44.0,
#   'Cabin': 'C78',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 37.0,
#   'Cabin': 'D35',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 54.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': 'G6',
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 62.0,
#   'Cabin': 'C87',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 41.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': 'B77',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 50.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 3.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 52.0,
#   'Cabin': 'E67',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 40.0,
#   'Cabin': 'B94',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 58.0,
#   'Cabin': 'C125',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': 'C99',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 41.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 37.0,
#   'Cabin': 'C118',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 63.0,
#   'Cabin': 'D7',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 7.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 65.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'A19',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': 'B49',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 36.0,
#   'Cabin': 'D',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': 'C22 C26',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': 'C106',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 50.0,
#   'Cabin': 'B58 B60',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'E101',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 0.92,
#   'Cabin': 'C22 C26',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': 'C65',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 30.0,
#   'Cabin': 'E36',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': 'C54',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': 'B57 B59 B63 B66',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 43.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 54.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': 'C7',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 40.0,
#   'Cabin': 'E34',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 8},
#  {'Age': 36.0,
#   'Cabin': 'C32',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 61.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': 'D',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 16.0,
#   'Cabin': 'B18',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 45.5,
#   'Cabin': 'C124',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': 'C91',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': 'C2',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 41.0,
#   'Cabin': 'E40',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 45.0,
#   'Cabin': 'T',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': 'F2',
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 24.0,
#   'Cabin': 'C23 C25 C27',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': 'F33',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 40.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 3.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'C128',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 15.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': 'E33',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 40.0,
#   'Cabin': nan,
#   'Parch': 4,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 60.0,
#   'Cabin': 'D37',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': 'B35',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': 'E50',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 3.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': 'C82',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 1.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 1.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 5},
#  {'Age': 36.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': 'B96 B98',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 23.0,
#   'Cabin': 'D36',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 24.0,
#   'Cabin': 'G6',
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 46.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 51.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 3.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': 'C78',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 44.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 10.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 32.0,
#   'Cabin': 'E10',
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': 'C52',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 50.0,
#   'Cabin': 'E44',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 14.0,
#   'Cabin': 'B96 B98',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 3,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 64.0,
#   'Cabin': 'C23 C25 C27',
#   'Parch': 4,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 4.0,
#   'Cabin': 'A34',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 13.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 5.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 52.0,
#   'Cabin': 'C104',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 30.0,
#   'Cabin': 'C111',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 49.0,
#   'Cabin': 'C92',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 65.0,
#   'Cabin': 'E38',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'D21',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 50.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 48.0,
#   'Cabin': 'E12',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 47.0,
#   'Cabin': 'E63',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 48.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 56.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 0.75,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 23.0,
#   'Cabin': 'D',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'A14',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 9.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 5},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 50.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 63.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': 'B49',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': 35.0,
#   'Cabin': 'C93',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 58.0,
#   'Cabin': 'B37',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 9.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 55.0,
#   'Cabin': 'C30',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 71.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 54.0,
#   'Cabin': 'D20',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': 'C22 C26',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 37.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': 'B79',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': 'C65',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 29.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': 'E25',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 54.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 47.0,
#   'Cabin': 'D46',
#   'Parch': 0,
#   'Pclass': 1,
# ...
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 6.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 50.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': 'E8',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 3},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': 'B5',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 11.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 48.0,
#   'Cabin': nan,
#   'Parch': 3,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 35.0,
#   'Cabin': 'B101',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'D45',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': 'C46',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 21.0,
#   'Cabin': 'B57 B59 B63 B66',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 2},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 70.0,
#   'Cabin': 'B22',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': 'D30',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 4.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 6.0,
#   'Cabin': 'E121',
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 48.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 0.67,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': 'B77',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 41.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 36.0,
#   'Cabin': 'B96 B98',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 51.0,
#   'Cabin': 'D11',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 48.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 57.0,
#   'Cabin': 'E77',
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 54.0,
#   'Cabin': nan,
#   'Parch': 3,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'F38',
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 5.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 43.0,
#   'Cabin': 'B3',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 13.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': 'B20',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 29.0,
#   'Cabin': 'D6',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 8.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 1.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 46.0,
#   'Cabin': 'B82 B84',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 8},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 49.0,
#   'Cabin': 'D17',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 34.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 11.0,
#   'Cabin': 'B96 B98',
#   'Parch': 2,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 0.42,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': 'A36',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': 'E8',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 6.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 4},
#  {'Age': 30.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'B102',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 31.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 43.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 10.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 3},
#  {'Age': 52.0,
#   'Cabin': 'B69',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 38.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': 'E121',
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 2.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 1.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 62.0,
#   'Cabin': 'B28',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 15.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 0.83,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 23.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': 'E49',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'C47',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 16.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 30.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 34.5,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 17.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 8},
#  {'Age': 35.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': 'C92',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 4.0,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 4},
#  {'Age': 74.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 9.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 16.0,
#   'Cabin': 'D28',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 44.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 18.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 45.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 51.0,
#   'Cabin': 'E17',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 3,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 41.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 2},
#  {'Age': 21.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 48.0,
#   'Cabin': 'D17',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 8},
#  {'Age': 24.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 42.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 31.0,
#   'Cabin': 'A24',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 4.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 1},
#  {'Age': 26.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 47.0,
#   'Cabin': 'D35',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 33.0,
#   'Cabin': 'B51 B53 B55',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 47.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 15.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 20.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 56.0,
#   'Cabin': 'C50',
#   'Parch': 1,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 1,
#   'Pclass': 2,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 33.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 22.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 28.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 25.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 39.0,
#   'Cabin': nan,
#   'Parch': 5,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': 27.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 2,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 19.0,
#   'Cabin': 'B42',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'female',
#   'SibSp': 0},
#  {'Age': nan,
#   'Cabin': nan,
#   'Parch': 2,
#   'Pclass': 3,
#   'Sex': 'female',
#   'SibSp': 1},
#  {'Age': 26.0,
#   'Cabin': 'C148',
#   'Parch': 0,
#   'Pclass': 1,
#   'Sex': 'male',
#   'SibSp': 0},
#  {'Age': 32.0,
#   'Cabin': nan,
#   'Parch': 0,
#   'Pclass': 3,
#   'Sex': 'male',
#   'SibSp': 0}]
